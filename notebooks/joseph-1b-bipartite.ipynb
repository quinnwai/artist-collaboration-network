# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import networkx as nx
from networkx.algorithms import bipartite

from tqdm.notebook import tqdm

# %%
# save each artist as json
for i, artist in tqdm(enumerate(final_artists)):
    with open(f"artists/artist{i}.json", "w") as outfile:
        json.dump(artist, outfile)

# %%
# save each track as json
for i, track in tqdm(enumerate(more_tracks)):
    with open(f"tracks/track{i}.json", "w") as outfile:
        json.dump(track, outfile)

# %%
artist_jsons = !cd "artists"; find *.json

artists_list = []
for file in artist_jsons:
    data = pd.read_json(f"artists/{file}", lines=True)
    artists_list.append(data)
    
artists = pd.concat(artists_list, ignore_index=True)
artists
# Out:
#                                           external_urls  \
# 0     {'spotify': 'https://open.spotify.com/artist/3...
# 1     {'spotify': 'https://open.spotify.com/artist/0...
# 2     {'spotify': 'https://open.spotify.com/artist/6...
# 3     {'spotify': 'https://open.spotify.com/artist/3...
# 4     {'spotify': 'https://open.spotify.com/artist/2...
# ...                                                 ...
# 4589  {'spotify': 'https://open.spotify.com/artist/5...
# 4590  {'spotify': 'https://open.spotify.com/artist/7...
# 4591  {'spotify': 'https://open.spotify.com/artist/1...
# 4592  {'spotify': 'https://open.spotify.com/artist/5...
# 4593  {'spotify': 'https://open.spotify.com/artist/6...
#
#                             followers  \
# 0        {'href': None, 'total': 149}
# 1      {'href': None, 'total': 43429}
# 2         {'href': None, 'total': 50}
# 3      {'href': None, 'total': 93588}
# 4      {'href': None, 'total': 69111}
# ...                               ...
# 4589    {'href': None, 'total': 2339}
# 4590   {'href': None, 'total': 46285}
# 4591  {'href': None, 'total': 647043}
# 4592    {'href': None, 'total': 2467}
# 4593     {'href': None, 'total': 526}
#
#                                                  genres  \
# 0                                                    []
# 1                                         [florida rap]
# 2                                                    []
# 3     [modern ska punk, punk, ska, ska punk, skate p...
# 4        [dubstep, edm, electro house, electronic trap]
# ...                                                 ...
# 4589                                                 []
# 4590                   [chicago rap, drill, vapor trap]
# 4591          [brooklyn drill, new york drill, nyc rap]
# 4592                                                 []
# 4593                                                 []
#
#                                                    href  \
# 0     https://api.spotify.com/v1/artists/3hTMyEnHbZ2...
# 1     https://api.spotify.com/v1/artists/09drtGC393C...
# 2     https://api.spotify.com/v1/artists/6c10vP5GpwZ...
# 3     https://api.spotify.com/v1/artists/31v7ijnAMVL...
# 4     https://api.spotify.com/v1/artists/21AUdblPrTR...
# ...                                                 ...
# 4589  https://api.spotify.com/v1/artists/53EmQSV3tRY...
# 4590  https://api.spotify.com/v1/artists/7AO1qih2zQe...
# 4591  https://api.spotify.com/v1/artists/1tG7s7S4sq2...
# 4592  https://api.spotify.com/v1/artists/55ny2DqS7aB...
# 4593  https://api.spotify.com/v1/artists/69m0yjx8ruK...
#
#                           id  \
# 0     3hTMyEnHbZ2fTRod9AzqEo
# 1     09drtGC393C6jGa05qYccB
# 2     6c10vP5GpwZ2j8CiuuWeS4
# 3     31v7ijnAMVL9V7Uzr1sFcI
# 4     21AUdblPrTRzkvJn8FGrlk
# ...                      ...
# 4589  53EmQSV3tRYsAlmM6kElwL
# 4590  7AO1qih2zQeI7WYTQxC5fQ
# 4591  1tG7s7S4sq2eFFW0QZyLbm
# 4592  55ny2DqS7aBuL4hinLeBfG
# 4593  69m0yjx8ruKebsRvbNuEDz
#
#                                                  images                  name  \
# 0     [{'height': 640, 'url': 'https://i.scdn.co/ima...          Bianca Sings
# 1     [{'height': 640, 'url': 'https://i.scdn.co/ima...                Kolyon
# 2                                                    []            Choppa Wop
# 3     [{'height': 640, 'url': 'https://i.scdn.co/ima...  The Suicide Machines
# 4     [{'height': 640, 'url': 'https://i.scdn.co/ima...          Nitti Gritti
# ...                                                 ...                   ...
# 4589  [{'height': 640, 'url': 'https://i.scdn.co/ima...             DaBoyDame
# 4590  [{'height': 640, 'url': 'https://i.scdn.co/ima...                 Tadoe
# 4591  [{'height': 640, 'url': 'https://i.scdn.co/ima...               Sheff G
# 4592  [{'height': 640, 'url': 'https://i.scdn.co/ima...            yoitsCrash
# 4593  [{'height': 751, 'url': 'https://i.scdn.co/ima...            Really Doe
#
#       popularity    type                                    uri
# 0             24  artist  spotify:artist:3hTMyEnHbZ2fTRod9AzqEo
# 1             37  artist  spotify:artist:09drtGC393C6jGa05qYccB
# 2             32  artist  spotify:artist:6c10vP5GpwZ2j8CiuuWeS4
# 3             49  artist  spotify:artist:31v7ijnAMVL9V7Uzr1sFcI
# 4             63  artist  spotify:artist:21AUdblPrTRzkvJn8FGrlk
# ...          ...     ...                                    ...
# 4589          37  artist  spotify:artist:53EmQSV3tRYsAlmM6kElwL
# 4590          53  artist  spotify:artist:7AO1qih2zQeI7WYTQxC5fQ
# 4591          75  artist  spotify:artist:1tG7s7S4sq2eFFW0QZyLbm
# 4592          27  artist  spotify:artist:55ny2DqS7aBuL4hinLeBfG
# 4593          50  artist  spotify:artist:69m0yjx8ruKebsRvbNuEDz
#
# [4594 rows x 10 columns]

# %%
copy_of_artists = artists.copy()
# tracks.head()
main_genre_for_artist = np.zeros(len(artists), dtype=list)
for i, artist_genres in enumerate(copy_of_artists['genres'].to_list()):
    if (len(artist_genres) == 0):
        main_genre_for_artist[i] = "other"
    elif ("chicago rap" in artist_genres):
        main_genre_for_artist[i] = 'chicago rap'
    else:
        main_genre_for_artist[i] = artist_genres[0]
unique_genres, unique_genre_counts = np.unique(main_genre_for_artist, return_counts=True)

# %%
unique_genres, unique_genre_counts = np.unique(main_genre_for_artist, return_counts=True)
chicago_rap_count = unique_genres[unique_genre_counts == unique_genre_counts.max()]
unique_genre_counts[unique_genre_counts == unique_genre_counts.max()]/unique_genre_counts.sum()
# Out:
# array([0.41663039])

# %%
other_artists = [len(i)==0 for i in artists['genres']]
# other_artists
copy_of_artists2 = copy_of_artists.drop(copy_of_artists[other_artists].index)
copy_of_artists2['genres'] = main_genre_for_artist[main_genre_for_artist != 'other']

# %%
num_tracks = !ls -l tracks/ | wc -l
track_jsons = [f"track{i}.json" for i in range(int(num_tracks[0].strip()))]
# print(track_jsons)
tracks_list = []
artists_list = []

for file in track_jsons:
    data = pd.read_json(f"tracks/{file}", lines=True)
    tracks_list.append(data)
    
tracks = pd.concat(tracks_list, ignore_index=True)
tracks

# %%
copy_of_tracks = tracks.copy()
# tracks.head()
artists_per_track = np.zeros(len(tracks), dtype=list)
for i, track in enumerate(tracks['artists'].to_list()):
    artists_per_track[i] = [artist['name'] for artist in track]
copy_of_tracks['artists'] = artists_per_track
copy_of_tracks
# Out:
#                           artists  \
# 0      [The Boys Choir Of Harlem]
# 1      [The Boys Choir Of Harlem]
# 2      [The Boys Choir Of Harlem]
# 3      [The Boys Choir Of Harlem]
# 4      [The Boys Choir Of Harlem]
# ...                           ...
# 45019                  [Bon Iver]
# 45020                  [Bon Iver]
# 45021                  [Bon Iver]
# 45022                  [Bon Iver]
# 45023                  [Bon Iver]
#
#                                        available_markets  disc_number  \
# 0      [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 1      [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 2      [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 3      [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 4      [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# ...                                                  ...          ...
# 45019  [AD, AL, AM, AT, AZ, BA, BE, BG, BY, CH, CW, C...            1
# 45020  [AD, AL, AM, AT, AZ, BA, BE, BG, BY, CH, CW, C...            1
# 45021  [AD, AL, AM, AT, AZ, BA, BE, BG, BY, CH, CW, C...            1
# 45022  [AD, AL, AM, AT, AZ, BA, BE, BG, BY, CH, CW, C...            1
# 45023  [AD, AL, AM, AT, AZ, BA, BE, BG, BY, CH, CW, C...            1
#
#        duration_ms  explicit  \
# 0           155440     False
# 1           255240     False
# 2           226040     False
# 3           223026     False
# 4           169680     False
# ...            ...       ...
# 45019       329279     False
# 45020       186132     False
# 45021       116919     False
# 45022       220732     False
# 45023       401426     False
#
#                                            external_urls  \
# 0      {'spotify': 'https://open.spotify.com/track/79...
# 1      {'spotify': 'https://open.spotify.com/track/57...
# 2      {'spotify': 'https://open.spotify.com/track/0A...
# 3      {'spotify': 'https://open.spotify.com/track/47...
# 4      {'spotify': 'https://open.spotify.com/track/5K...
# ...                                                  ...
# 45019  {'spotify': 'https://open.spotify.com/track/7v...
# 45020  {'spotify': 'https://open.spotify.com/track/6a...
# 45021  {'spotify': 'https://open.spotify.com/track/0X...
# 45022  {'spotify': 'https://open.spotify.com/track/64...
# 45023  {'spotify': 'https://open.spotify.com/track/1D...
#
#                                                     href  \
# 0      https://api.spotify.com/v1/tracks/792ywURG9Ayc...
# 1      https://api.spotify.com/v1/tracks/57rGxFsw7gBi...
# 2      https://api.spotify.com/v1/tracks/0AuzsPNc3GSU...
# 3      https://api.spotify.com/v1/tracks/47jySDLe5rBz...
# 4      https://api.spotify.com/v1/tracks/5KIH6pSKTNrD...
# ...                                                  ...
# 45019  https://api.spotify.com/v1/tracks/7vE7w0zMSYRR...
# 45020  https://api.spotify.com/v1/tracks/6afJTmreY8lM...
# 45021  https://api.spotify.com/v1/tracks/0XltgXfjLVvx...
# 45022  https://api.spotify.com/v1/tracks/64jVNNTwT0Nd...
# 45023  https://api.spotify.com/v1/tracks/1D39ZETXfcAF...
#
#                            id  is_local                            name  \
# 0      792ywURG9AycMjt9I1TEgD     False     Everytime I Feel the Spirit
# 1      57rGxFsw7gBiGOyuqYXzq7     False                   Go Down Moses
# 2      0AuzsPNc3GSUHVpfLFJqGZ     False  Children, Go Where I Send Thee
# 3      47jySDLe5rBzXnj2sHzBVG     False  Little David Play On Your Harp
# 4      5KIH6pSKTNrDdsHJDmckGi     False             Ride On, King Jesus
# ...                       ...       ...                             ...
# 45019  7vE7w0zMSYRR29fIZBTiyp     False                      Blindsided
# 45020  6afJTmreY8lMnG9F4Uo1tM     False                   Creature Fear
# 45021  0XltgXfjLVvxY0intOijLq     False                            Team
# 45022  64jVNNTwT0NdQbqqUIa8gi     False                        For Emma
# 45023  1D39ZETXfcAFYaGruPHEzB     False                       re:stacks
#
#                                              preview_url  track_number   type  \
# 0      https://p.scdn.co/mp3-preview/eaa0c04b30543f95...             1  track
# 1      https://p.scdn.co/mp3-preview/8333db97e6969f19...             2  track
# 2      https://p.scdn.co/mp3-preview/f6a87fcf1d683339...             3  track
# 3      https://p.scdn.co/mp3-preview/85928da90fb8608b...             4  track
# 4      https://p.scdn.co/mp3-preview/9b3f362b8e576d28...             5  track
# ...                                                  ...           ...    ...
# 45019  https://p.scdn.co/mp3-preview/fd135167b431f87b...             5  track
# 45020  https://p.scdn.co/mp3-preview/8002c944ece0008e...             6  track
# 45021  https://p.scdn.co/mp3-preview/9cb3b36f94689606...             7  track
# 45022  https://p.scdn.co/mp3-preview/86359673ac343684...             8  track
# 45023  https://p.scdn.co/mp3-preview/af0b95ba92bca5f0...             9  track
#
#                                         uri
# 0      spotify:track:792ywURG9AycMjt9I1TEgD
# 1      spotify:track:57rGxFsw7gBiGOyuqYXzq7
# 2      spotify:track:0AuzsPNc3GSUHVpfLFJqGZ
# 3      spotify:track:47jySDLe5rBzXnj2sHzBVG
# 4      spotify:track:5KIH6pSKTNrDdsHJDmckGi
# ...                                     ...
# 45019  spotify:track:7vE7w0zMSYRR29fIZBTiyp
# 45020  spotify:track:6afJTmreY8lMnG9F4Uo1tM
# 45021  spotify:track:0XltgXfjLVvxY0intOijLq
# 45022  spotify:track:64jVNNTwT0NdQbqqUIa8gi
# 45023  spotify:track:1D39ZETXfcAFYaGruPHEzB
#
# [45024 rows x 14 columns]

# %%
# generating test data
songs_data = {'id': [1, 2, 3, 4], 'title': ['songone', 'songtwo', 'songthree', 'songfour'], 'artists': [['kanye'], ['kanye', 'drake'], ['drake', 'durk'], ['drake', 'durk']]}
songs = pd.DataFrame(data=songs_data)
artists_data = {'id': ['a', 'b', 'c'], 'name': ['kanye', 'drake', 'durk'], 'genre': ['chicago rap', 'pop rap', 'chicago rap']}
artists = pd.DataFrame(data=artists_data)

# %%
songs
# Out:
#    id      title         artists
# 0   1    songone         [kanye]
# 1   2    songtwo  [kanye, drake]
# 2   3  songthree   [drake, durk]
# 3   4   songfour   [drake, durk]

# %%
copy_of_tracks.head()
# Out:
#                       artists  \
# 0  [The Boys Choir Of Harlem]
# 1  [The Boys Choir Of Harlem]
# 2  [The Boys Choir Of Harlem]
# 3  [The Boys Choir Of Harlem]
# 4  [The Boys Choir Of Harlem]
#
#                                    available_markets  disc_number  \
# 0  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 1  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 2  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 3  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 4  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
#
#    duration_ms  explicit                                      external_urls  \
# 0       155440     False  {'spotify': 'https://open.spotify.com/track/79...
# 1       255240     False  {'spotify': 'https://open.spotify.com/track/57...
# 2       226040     False  {'spotify': 'https://open.spotify.com/track/0A...
# 3       223026     False  {'spotify': 'https://open.spotify.com/track/47...
# 4       169680     False  {'spotify': 'https://open.spotify.com/track/5K...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/792ywURG9Ayc...  792ywURG9AycMjt9I1TEgD
# 1  https://api.spotify.com/v1/tracks/57rGxFsw7gBi...  57rGxFsw7gBiGOyuqYXzq7
# 2  https://api.spotify.com/v1/tracks/0AuzsPNc3GSU...  0AuzsPNc3GSUHVpfLFJqGZ
# 3  https://api.spotify.com/v1/tracks/47jySDLe5rBz...  47jySDLe5rBzXnj2sHzBVG
# 4  https://api.spotify.com/v1/tracks/5KIH6pSKTNrD...  5KIH6pSKTNrDdsHJDmckGi
#
#    is_local                            name  \
# 0     False     Everytime I Feel the Spirit
# 1     False                   Go Down Moses
# 2     False  Children, Go Where I Send Thee
# 3     False  Little David Play On Your Harp
# 4     False             Ride On, King Jesus
#
#                                          preview_url  track_number   type  \
# 0  https://p.scdn.co/mp3-preview/eaa0c04b30543f95...             1  track
# 1  https://p.scdn.co/mp3-preview/8333db97e6969f19...             2  track
# 2  https://p.scdn.co/mp3-preview/f6a87fcf1d683339...             3  track
# 3  https://p.scdn.co/mp3-preview/85928da90fb8608b...             4  track
# 4  https://p.scdn.co/mp3-preview/9b3f362b8e576d28...             5  track
#
#                                     uri
# 0  spotify:track:792ywURG9AycMjt9I1TEgD
# 1  spotify:track:57rGxFsw7gBiGOyuqYXzq7
# 2  spotify:track:0AuzsPNc3GSUHVpfLFJqGZ
# 3  spotify:track:47jySDLe5rBzXnj2sHzBVG
# 4  spotify:track:5KIH6pSKTNrDdsHJDmckGi

# %%
artists
# Out:
#   id   name        genre
# 0  a  kanye  chicago rap
# 1  b  drake      pop rap
# 2  c   durk  chicago rap

# %%
copy_of_artists2.head()
# Out:
#                                        external_urls  \
# 1  {'spotify': 'https://open.spotify.com/artist/0...
# 3  {'spotify': 'https://open.spotify.com/artist/3...
# 4  {'spotify': 'https://open.spotify.com/artist/2...
# 6  {'spotify': 'https://open.spotify.com/artist/0...
# 7  {'spotify': 'https://open.spotify.com/artist/6...
#
#                            followers           genres  \
# 1     {'href': None, 'total': 43429}      florida rap
# 3     {'href': None, 'total': 93588}  modern ska punk
# 4     {'href': None, 'total': 69111}          dubstep
# 6  {'href': None, 'total': 23466400}    colombian pop
# 7    {'href': None, 'total': 165803}          chutney
#
#                                                 href                      id  \
# 1  https://api.spotify.com/v1/artists/09drtGC393C...  09drtGC393C6jGa05qYccB
# 3  https://api.spotify.com/v1/artists/31v7ijnAMVL...  31v7ijnAMVL9V7Uzr1sFcI
# 4  https://api.spotify.com/v1/artists/21AUdblPrTR...  21AUdblPrTRzkvJn8FGrlk
# 6  https://api.spotify.com/v1/artists/0EmeFodog0B...  0EmeFodog0BfCgMzAIvKQp
# 7  https://api.spotify.com/v1/artists/6wxP7SSzfvi...  6wxP7SSzfvi21Cnl8JicdQ
#
#                                               images                  name  \
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...                Kolyon
# 3  [{'height': 640, 'url': 'https://i.scdn.co/ima...  The Suicide Machines
# 4  [{'height': 640, 'url': 'https://i.scdn.co/ima...          Nitti Gritti
# 6  [{'height': 640, 'url': 'https://i.scdn.co/ima...               Shakira
# 7  [{'height': 640, 'url': 'https://i.scdn.co/ima...        Machel Montano
#
#    popularity    type                                    uri
# 1          37  artist  spotify:artist:09drtGC393C6jGa05qYccB
# 3          49  artist  spotify:artist:31v7ijnAMVL9V7Uzr1sFcI
# 4          63  artist  spotify:artist:21AUdblPrTRzkvJn8FGrlk
# 6          86  artist  spotify:artist:0EmeFodog0BfCgMzAIvKQp
# 7          58  artist  spotify:artist:6wxP7SSzfvi21Cnl8JicdQ

# %%
# creating the initial bipartite graph
# I need to do this for each year

B = nx.Graph()

# adding nodes for songs and artists

B.add_nodes_from((copy_of_tracks['name']).to_list(), bipartite=0)
for idx, artist in copy_of_artists2.iterrows():
#     print(f"added node '{artist['name']}' with atrribute '{artist['genre']}'")
    B.add_node(artist['name'], genre=artist['genres'])
    
print(B.nodes.data())
    
# adding an edge if an artist is on a song
for index, song in copy_of_tracks.iterrows():
    for index, artist in copy_of_artists2.iterrows():
        if (artist['name'] in song['artists']):
#             print(f'add edge between {song["title"]} and {artist["name"]}')
            B.add_edges_from([(song["name"], artist["name"])])

print(B.edges.data())
# print(bipartite.is_bipartite(B))
# G = bipartite.weighted_projected_graph(B, [1, 3])
# Out:
# [('Everytime I Feel the Spirit', {'bipartite': 0}), ('Go Down Moses', {'bipartite': 0}), ('Children, Go Where I Send Thee', {'bipartite': 0}), ('Little David Play On Your Harp', {'bipartite': 0}), ('Ride On, King Jesus', {'bipartite': 0}), ('Ezekiel Saw De Wheel', {'bipartite': 0}), ("I've Been Buked", {'bipartite': 0}), ('If I Got My Ticket, Can I Ride', {'bipartite': 0}), ('Mary Was the Queen of Galilee', {'bipartite': 0}), ('Amazing Grace', {'bipartite': 0}), ('I Can Tell the World', {'bipartite': 0}), ('Precious Lord', {'bipartite': 0}), ('Kumbaya My Lord', {'bipartite': 0}), ('Oh Freedom', {'bipartite': 0}), ('This Is The Day', {'bipartite': 0}), ('Know Your Life Will change This Christmas', {'bipartite': 0}), ('We Got Shoes', {'bipartite': 0}), ("We're So Glad U Came", {'bipartite': 0}), ('Fix Me jesus', {'bipartite': 0}), ('This Is The Day (remix)', {'bipartite': 0}), ('We Got Shoes (remix)', {'bipartite': 0}), ("We're So Glad U Came (remix)", {'bipartite': 0}), ('Fix Me Jesus (remix)', {'bipartite': 0}), ("You'll Never Walk Alone", {'bipartite': 0}), ('Let There Be Peace on Earth', {'bipartite': 0}), ('Children Of The World', {'bipartite': 0}), ('My Shepherd Will Supply My Need', {'bipartite': 0}), ('United We Stand', {'bipartite': 0}), ('We Shall Overcome', {'bipartite': 0}), ('Lift Every Voice and Sing', {'bipartite': 0}), ('God of Our Fathers', {'bipartite': 0}), ('Man in the Mirror/I Believe I Can Fly', {'bipartite': 0}), ('Kyrie', {'bipartite': 0}), ('Gloria', {'bipartite': 0}), ('Credo', {'bipartite': 0}), ('Sanctus', {'bipartite': 0}), ('Benedictus', {'bipartite': 0}), ('Agnus Dei', {'bipartite': 0}), ('Oh Lord, Open Our Lips', {'bipartite': 0}), ('Come Let Us Sing Unto The Lord', {'bipartite': 0}), ('Let Our Enemies Be As Chaff', {'bipartite': 0}), ('Sing Unto The Lord A New Song', {'bipartite': 0}), ('Every Time I Feel The Spirit', {'bipartite': 0}), ('Children Go Where I Send Thee', {'bipartite': 0}), ('Little David, Play on Your Harp', {'bipartite': 0}), ('O Come All Ye Faithful', {'bipartite': 0}), ('Carol of the Bells', {'bipartite': 0}), ('The Christmas Song', {'bipartite': 0}), ('Silent Night', {'bipartite': 0}), ('Have Yourself a Merry Little Christmas', {'bipartite': 0}), ('Oh Holy Night', {'bipartite': 0}), ('Hark the Herald Angels Sing', {'bipartite': 0}), ('Joy to the World', {'bipartite': 0}), ('Little Drummer Boy', {'bipartite': 0}), ('Let It Snow, Let It Snow', {'bipartite': 0}), ('This Christmas', {'bipartite': 0}), ('Back to You', {'bipartite': 0}), ('Heros', {'bipartite': 0}), ('I Need to Know', {'bipartite': 0}), ('Interlude: I Trust in God', {'bipartite': 0}), ('Interlude: With My Whole Heart', {'bipartite': 0}), ('Overjoyed', {'bipartite': 0}), ('Interlude: Fuguetta', {'bipartite': 0}), ('Bayethe Mandela', {'bipartite': 0}), ('Power', {'bipartite': 0}), ('Hold On', {'bipartite': 0}), ("Interlude: Don't Compare My Singin'", {'bipartite': 0}), ('Rough Crossing', {'bipartite': 0}), ('We Can Make It Better', {'bipartite': 0}), ('Interlude: Hallelu!', {'bipartite': 0}), ('Children of the World', {'bipartite': 0}), ('O Holy Night', {'bipartite': 0}), ('I Wonder as I Wander', {'bipartite': 0}), ('Winter Wonderland', {'bipartite': 0}), ('Let Is Snow, Let It Snow', {'bipartite': 0}), ('White Christmas', {'bipartite': 0}), ('O Tannenbaum', {'bipartite': 0}), ('Go Tell It on the Mountain', {'bipartite': 0}), ('Sweet Little Jesus Boy', {'bipartite': 0}), ("Ode for St. Cecilia's Day, HWV 76: I. Overture", {'bipartite': 0}), ("Ode for St. Cecilia's Day, HWV 76: II. Recitative (Tenor)", {'bipartite': 0}), ("Ode for St. Cecilia's Day, HWV 76: III. Chorus", {'bipartite': 0}), ("Ode for St. Cecilia's Day, HWV 76: IV. Aria (Soprano)", {'bipartite': 0}), ("Ode for St. Cecilia's Day, HWV 76: V. Aria (Tenor) and Chorus", {'bipartite': 0}), ("Ode for St. Cecilia's Day, HWV 76: VI. March", {'bipartite': 0}), ("Ode for St. Cecilia's Day, HWV 76: VII. Aria (Soprano)", {'bipartite': 0}), ("Ode for St. Cecilia's Day,  ...
# [('Everytime I Feel the Spirit', 'The Boys Choir Of Harlem', {}), ('Go Down Moses', 'The Boys Choir Of Harlem', {}), ('Children, Go Where I Send Thee', 'The Boys Choir Of Harlem', {}), ('Little David Play On Your Harp', 'The Boys Choir Of Harlem', {}), ('Ride On, King Jesus', 'The Boys Choir Of Harlem', {}), ('Ezekiel Saw De Wheel', 'The Boys Choir Of Harlem', {}), ("I've Been Buked", 'The Boys Choir Of Harlem', {}), ('If I Got My Ticket, Can I Ride', 'The Boys Choir Of Harlem', {}), ('Mary Was the Queen of Galilee', 'The Boys Choir Of Harlem', {}), ('Amazing Grace', 'The Boys Choir Of Harlem', {}), ('I Can Tell the World', 'The Boys Choir Of Harlem', {}), ('Precious Lord', 'The Boys Choir Of Harlem', {}), ('Precious Lord', "Chicago Children's Choir", {}), ('Kumbaya My Lord', 'The Boys Choir Of Harlem', {}), ('Oh Freedom', 'The Boys Choir Of Harlem', {}), ('This Is The Day', 'The Boys Choir Of Harlem', {}), ('This Is The Day', 'Fred Hammond', {}), ('Know Your Life Will change This Christmas', 'The Boys Choir Of Harlem', {}), ('We Got Shoes', 'The Boys Choir Of Harlem', {}), ("We're So Glad U Came", 'The Boys Choir Of Harlem', {}), ('Fix Me jesus', 'The Boys Choir Of Harlem', {}), ('This Is The Day (remix)', 'The Boys Choir Of Harlem', {}), ('We Got Shoes (remix)', 'The Boys Choir Of Harlem', {}), ("We're So Glad U Came (remix)", 'The Boys Choir Of Harlem', {}), ('Fix Me Jesus (remix)', 'The Boys Choir Of Harlem', {}), ("You'll Never Walk Alone", 'The Boys Choir Of Harlem', {}), ('Let There Be Peace on Earth', 'The Boys Choir Of Harlem', {}), ('Children Of The World', 'The Boys Choir Of Harlem', {}), ('My Shepherd Will Supply My Need', 'The Boys Choir Of Harlem', {}), ('United We Stand', 'The Boys Choir Of Harlem', {}), ('We Shall Overcome', 'The Boys Choir Of Harlem', {}), ('We Shall Overcome', "Chicago Children's Choir", {}), ('Lift Every Voice and Sing', 'The Boys Choir Of Harlem', {}), ('God of Our Fathers', 'The Boys Choir Of Harlem', {}), ('Man in the Mirror/I Believe I Can Fly', 'The Boys Choir Of Harlem', {}), ('Kyrie', 'The Boys Choir Of Harlem', {}), ('Gloria', 'The Boys Choir Of Harlem', {}), ('Credo', 'The Boys Choir Of Harlem', {}), ('Sanctus', 'The Boys Choir Of Harlem', {}), ('Benedictus', 'The Boys Choir Of Harlem', {}), ('Agnus Dei', 'The Boys Choir Of Harlem', {}), ('Oh Lord, Open Our Lips', 'The Boys Choir Of Harlem', {}), ('Come Let Us Sing Unto The Lord', 'The Boys Choir Of Harlem', {}), ('Let Our Enemies Be As Chaff', 'The Boys Choir Of Harlem', {}), ('Sing Unto The Lord A New Song', 'The Boys Choir Of Harlem', {}), ('Every Time I Feel The Spirit', 'The Boys Choir Of Harlem', {}), ('Children Go Where I Send Thee', 'The Boys Choir Of Harlem', {}), ('Little David, Play on Your Harp', 'The Boys Choir Of Harlem', {}), ('O Come All Ye Faithful', 'The Boys Choir Of Harlem', {}), ('O Come All Ye Faithful', 'Kirk Franklin', {}), ('Carol of the Bells', 'The Boys Choir Of Harlem', {}), ('Carol of the Bells', "Chicago Children's Choir", {}), ('The Christmas Song', 'The Boys Choir Of Harlem', {}), ('The Christmas Song', "Chicago Children's Choir", {}), ('The Christmas Song', 'Kenny G', {}), ('Silent Night', 'The Boys Choir Of Harlem', {}), ('Silent Night', 'New York Choral Artists', {}), ('Silent Night', "Orchestra of St. Luke's", {}), ('Silent Night', 'Kathleen Battle', {}), ('Silent Night', 'Leonard Slatkin', {}), ('Silent Night', 'Terrace Martin', {}), ('Silent Night', "Chicago Children's Choir", {}), ('Silent Night', 'SWV', {}), ('Silent Night', 'Justin Bieber', {}), ('Silent Night', 'Kenny G', {}), ('Silent Night', 'Bronn Journey', {}), ('Silent Night', 'Kirk Franklin', {}), ('Silent Night', 'Sugarland', {}), ('Have Yourself a Merry Little Christmas', 'The Boys Choir Of Harlem', {}), ('Have Yourself a Merry Little Christmas', 'Kenny G', {}), ('Oh Holy Night', 'The Boys Choir Of Harlem', {}), ('Oh Holy Night', 'En Vogue', {}), ('Oh Holy Night', 'Bronn Journey', {}), ('Oh Holy Night', 'Kenny G', {}), ('Hark the Her ...

# %%
# projecting the bipartite graph onto the artists
song_nodes, artist_nodes = bipartite.sets(B)
G = bipartite.weighted_projected_graph(B, artist_nodes)
print("nodes")
print(G.nodes.data())
print("\nedges")
print(G.edges.data())
# Out:
# ---------------------------------------------------------------------------
# AmbiguousSolution                         Traceback (most recent call last)
# <ipython-input-141-b84bf8db2b5b> in <module>
#       1 # projecting the bipartite graph onto the artists
# ----> 2 song_nodes, artist_nodes = bipartite.sets(B)
#       3 G = bipartite.weighted_projected_graph(B, artist_nodes)
#       4 print("nodes")
#       5 print(G.nodes.data())
#
# /opt/anaconda3/lib/python3.8/site-packages/networkx/algorithms/bipartite/basic.py in sets(G, top_nodes)
#     199         if not is_connected(G):
#     200             msg = "Disconnected graph: Ambiguous solution for bipartite sets."
# --> 201             raise nx.AmbiguousSolution(msg)
#     202         c = color(G)
#     203         X = {n for n, is_top in c.items() if is_top}
#
# AmbiguousSolution: Disconnected graph: Ambiguous solution for bipartite sets.

# %%
nx.write_gexf(G, "first_test_graph.gexf")

# %%
nx.write_gexf(B, "first_test_graph.gexf")

# %%
# Out:
# False
